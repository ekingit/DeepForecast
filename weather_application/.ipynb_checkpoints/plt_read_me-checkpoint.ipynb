# %%
import matplotlib.pyplot as plt
from data import Weather_Data

# %%
path = 'weather_prediction_dataset.csv'
nat_data = Weather_Data(path,'BASEL_temp_max')
X = nat_data.df_raw

# %%
plt.figure(figsize=(10,4))
plt.plot(X[0:30])
plt.scatter([i for i in range(0,14)],X[0:14])
plt.scatter([i for i in range(14,21)],X[14:21],color='r')
plt.xlabel('time (days)')
plt.ylabel('temperature ($^ \circ C$)')
plt.savefig('weather_application')
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\c'
# <>:6: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\PC\AppData\Local\Temp\ipykernel_6836\1528662577.py:6: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('temperature ($^ \circ C$)')
