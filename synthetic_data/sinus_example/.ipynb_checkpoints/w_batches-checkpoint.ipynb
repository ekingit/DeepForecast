# %%
from data import Data
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset

# %%
data = Data(0.01,1000,0.)
X, Y = data[150]
X = X.unsqueeze(-1)
print(X.shape,Y.shape)
# Out:
# torch.Size([850, 150, 1]) torch.Size([850, 1])

# %%
ds = TensorDataset(X,Y)
dl = DataLoader(ds,batch_size=100, shuffle=False)

# %%
class RNN_model(nn.Module):
    def __init__(self, num_inputs, num_hiddens,num_out=1):
        super().__init__()
        self.num_inputs = num_inputs
        self.num_hiddens = num_hiddens
        self.rnn = nn.RNN(num_inputs, num_hiddens, batch_first=True)
        self.linear = nn.Linear(num_hiddens, num_out)
    def forward(self, X, H):
        state, H = self.rnn(X,H) 
        pred = self.linear(H[0]) #checked! H[0]=state[:,-1,:]
        return pred # size = (batch_size, 1)

# %%
def rnn_train(model, dl_train, optimizer, loss, hidden_size, device = 'cpu'):
    total_loss = 0
    for X, Y in dl_train:
        model.train()
        X, Y = X.to(device), Y.to(device)
        H = torch.zeros(1,X.shape[0],hidden_size)
        Y_hat = model(X,H)
        batch_loss = loss(Y_hat,Y)
        batch_loss.backward()
        optimizer.step()
        total_loss += batch_loss.detach()
    total_loss = torch.sqrt(total_loss/len(ds))
    if epoch %10 ==0:
        print(total_loss) #MSE loss

# %%
hidden_size = 2
mse_loss = nn.MSELoss(reduction='sum')
rnn_model = RNN_model(1,hidden_size)
optimizer = torch.optim.Adam(rnn_model.parameters(), lr=1e-4)
for epoch in range(1000):
    rnn_train(rnn_model, dl, optimizer, mse_loss, hidden_size)
# Out:
# tensor(0.6348)
# tensor(0.6293)
# tensor(0.6221)
# tensor(0.6143)
# tensor(0.6058)
# tensor(0.5964)
# tensor(0.5861)
# tensor(0.5751)
# tensor(0.5633)
# tensor(0.5506)
# tensor(0.5369)
# tensor(0.5225)
# tensor(0.5072)
# tensor(0.4909)
# tensor(0.4738)
# tensor(0.4557)
# tensor(0.4367)
# tensor(0.4170)
# tensor(0.3965)
# tensor(0.3753)
# tensor(0.3534)
# tensor(0.3308)
# tensor(0.3074)
# tensor(0.2833)
# tensor(0.2586)
# tensor(0.2333)
# tensor(0.2079)
# tensor(0.1824)
# tensor(0.1566)
# tensor(0.1307)
# tensor(0.1056)
# tensor(0.0833)
# tensor(0.0657)
# tensor(0.0555)
# tensor(0.0593)
# tensor(0.0765)
# tensor(0.0985)
# tensor(0.1212)
# tensor(0.1457)
# tensor(0.1711)
# tensor(0.1944)
# tensor(0.2164)
# tensor(0.2384)
# tensor(0.2581)
# tensor(0.2745)
# tensor(0.2895)
# tensor(0.3021)
# tensor(0.3104)
# tensor(0.3164)
# tensor(0.3200)
# tensor(0.3192)
# tensor(0.3144)
# tensor(0.3076)
# tensor(0.2982)
# tensor(0.2850)
# tensor(0.2703)
# tensor(0.2555)
# tensor(0.2391)
# tensor(0.2207)
# tensor(0.2031)
# tensor(0.1879)
# tensor(0.1731)
# tensor(0.1580)
# tensor(0.1461)
# tensor(0.1395)
# tensor(0.1354)
# tensor(0.1313)
# tensor(0.1293)
# tensor(0.1320)
# tensor(0.1379)
# tensor(0.1440)
# tensor(0.1490)
# tensor(0.1546)
# tensor(0.1619)
# tensor(0.1698)
# tensor(0.1764)
# tensor(0.1806)
# tensor(0.1837)
# tensor(0.1875)
# tensor(0.1918)
# tensor(0.1951)
# tensor(0.1960)
# tensor(0.1947)
# tensor(0.1931)
# tensor(0.1917)
# tensor(0.1900)
# tensor(0.1870)
# tensor(0.1823)
# tensor(0.1762)
# tensor(0.1697)
# tensor(0.1635)
# tensor(0.1576)
# tensor(0.1509)
# tensor(0.1428)
# tensor(0.1339)
# tensor(0.1252)
# tensor(0.1177)
# tensor(0.1112)
# tensor(0.1047)
# tensor(0.0977)

# %% [markdown]
# Analyze the learning pattern. Even though loss is not stable, the model is able to minimize the loss since Adam optimizer decreases lr gradually.

# %%
H = torch.zeros(1,850,2)
a = rnn_model(X,H).detach()
plt.plot(data.x[150:])
plt.plot(a)

# %%
def predictor(X,k):
    '''Calculates first (len(X)) predictions from given data X, then using the prediction data,
    calculates next k-step predictions.
    '''
    H_0 = torch.zeros(1,X.shape[0],2) # size (1,850,2)
    X_0 = rnn_model(X,H).detach() #size (850,1)
    X_next = torch.cat([X[-1,1:],X_0[-1].unsqueeze(-1)]) #first prediction concatinated with the last 149 values. size(150,1)
    H_next = torch.zeros(1,2)
    for i in range(k):
        X_next = torch.cat([X_next[1:],rnn_model(X_next,H_next).detach().unsqueeze(-1)]) 
        X_0 = torch.cat([X_0,X_next[-1].unsqueeze(-1)])
    return X_0 # Checked! Analyzed the results in detail.

# %%
result = predictor(X,50)
plt.plot(data.x[-850:])
plt.plot(result)

# %% [markdown]
# Our code works for seen data but explodes quickly for future prediction since we only used teacher forcing.

# %%
result = predictor(X,50)
plt.plot(result)

# %%
list(rnn_model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-1.1951],
#          [ 1.1668]], requires_grad=True),
#  Parameter containing:
#  tensor([[-0.1579, -0.4251],
#          [ 0.5173, -0.5380]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.6684, -0.0266], requires_grad=True),
#  Parameter containing:
#  tensor([-0.7784, -0.3682], requires_grad=True),
#  Parameter containing:
#  tensor([[-1.0125,  0.8355]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.3033], requires_grad=True)]
